# %% [markdown]
# # Scratch analysis
#
# Light sandbox for a blog note, figure, or quick exploration.
# Run `./scripts/install_kernel.sh` once, then select this project's kernel.

# %%
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt

print(f"numpy {np.__version__}, pandas {pd.__version__}, polars {pl.__version__}")
