# %% [markdown]
# # Analysis
#
# Select the project kernel (run `./scripts/install_kernel.sh` once), then start here.

# %%
import numpy as np
import pandas as pd
import polars as pl
import pymc as pm
import arviz as az

print(f"numpy {np.__version__}, pandas {pd.__version__}, polars {pl.__version__}")
print(f"pymc {pm.__version__}, arviz {az.__version__}")
